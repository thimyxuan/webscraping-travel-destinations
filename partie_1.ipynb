# %% [markdown]
# # PARTIE 1 : Données météorologiques

# %% [markdown]
# ## Import librairies

# %%
import requests
import pandas as pd
import numpy as np 
import json

# %% [markdown]
# ## Liste des villes
#
# Nous travaillons avec les 35 meilleures villes françaises à visiter.

# %%
cities = [
    "Mont Saint Michel",
    "St Malo",
    "Bayeux",
    "Le Havre",
    "Rouen",
    "Paris",
    "Amiens",
    "Lille",
    "Strasbourg",
    "Chateau du Haut Koenigsbourg",
    "Colmar",
    "Eguisheim",
    "Besancon",
    "Dijon",
    "Annecy",
    "Grenoble",
    "Lyon",
    "Gorges du Verdon",
    "Bormes les Mimosas",
    "Cassis",
    "Marseille",
    "Aix en Provence",
    "Avignon",
    "Uzes",
    "Nimes",
    "Aigues Mortes",
    "Saintes Maries de la mer",
    "Collioure",
    "Carcassonne",
    "Ariege",
    "Toulouse",
    "Montauban",
    "Biarritz",
    "Bayonne",
    "La Rochelle"
]

# %% [markdown]
# ## API Nominatim
#
# Nous utilisons l'API Nominatim pour récuperer les données GPS (latitude et longitude) des 35 villes.

# %%
r = requests.get('https://nominatim.openstreetmap.org/search?city=Paris&country=France&format=json')
r.content
# Out:
# b'[{"place_id":115350921,"licence":"Data \xc2\xa9 OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright","osm_type":"relation","osm_id":7444,"lat":"48.8588897","lon":"2.3200410217200766","class":"boundary","type":"administrative","place_rank":15,"importance":0.8317101715588673,"addresstype":"suburb","name":"Paris","display_name":"Paris, \xc3\x8ele-de-France, France m\xc3\xa9tropolitaine, France","boundingbox":["48.8155755","48.9021560","2.2241220","2.4697602"]},{"place_id":114827617,"licence":"Data \xc2\xa9 OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright","osm_type":"relation","osm_id":71525,"lat":"48.8534951","lon":"2.3483915","class":"boundary","type":"administrative","place_rank":12,"importance":0.8317101715588673,"addresstype":"city","name":"Paris","display_name":"Paris, \xc3\x8ele-de-France, France m\xc3\xa9tropolitaine, France","boundingbox":["48.8155755","48.9021560","2.2241220","2.4697602"]},{"place_id":114994164,"licence":"Data \xc2\xa9 OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright","osm_type":"relation","osm_id":1641193,"lat":"48.8588897","lon":"2.3200410217200766","class":"boundary","type":"administrative","place_rank":14,"importance":0.4283953917728152,"addresstype":"city_district","name":"Paris","display_name":"Paris, \xc3\x8ele-de-France, France m\xc3\xa9tropolitaine, France","boundingbox":["48.8155755","48.9021560","2.2241220","2.4697602"]}]'

# %%
r.json()
# Out:
# [{'place_id': 115350921,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 7444,
#   'lat': '48.8588897',
#   'lon': '2.3200410217200766',
#   'class': 'boundary',
#   'type': 'administrative',
#   'place_rank': 15,
#   'importance': 0.8317101715588673,
#   'addresstype': 'suburb',
#   'name': 'Paris',
#   'display_name': 'Paris, Île-de-France, France métropolitaine, France',
#   'boundingbox': ['48.8155755', '48.9021560', '2.2241220', '2.4697602']},
#  {'place_id': 114827617,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 71525,
#   'lat': '48.8534951',
#   'lon': '2.3483915',
#   'class': 'boundary',
#   'type': 'administrative',
#   'place_rank': 12,
#   'importance': 0.8317101715588673,
#   'addresstype': 'city',
#   'name': 'Paris',
#   'display_name': 'Paris, Île-de-France, France métropolitaine, France',
#   'boundingbox': ['48.8155755', '48.9021560', '2.2241220', '2.4697602']},
#  {'place_id': 114994164,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 1641193,
#   'lat': '48.8588897',
#   'lon': '2.3200410217200766',
#   'class': 'boundary',
#   'type': 'administrative',
#   'place_rank': 14,
#   'importance': 0.4283953917728152,
#   'addresstype': 'city_district',
#   'name': 'Paris',
#   'display_name': 'Paris, Île-de-France, France métropolitaine, France',
#   'boundingbox': ['48.8155755', '48.9021560', '2.2241220', '2.4697602']}]

# %% [markdown]
# Notre liste de villes contient des espaces. Nous remplaçons les espaces par le caractère '+' pour les futures requêtes API.

# %%
cities_for_api = []
for i, city in enumerate(cities): 
    cities_for_api.append(city.replace(' ','+'))
cities_for_api
# Out:
# ['Mont+Saint+Michel',
#  'St+Malo',
#  'Bayeux',
#  'Le+Havre',
#  'Rouen',
#  'Paris',
#  'Amiens',
#  'Lille',
#  'Strasbourg',
#  'Chateau+du+Haut+Koenigsbourg',
#  'Colmar',
#  'Eguisheim',
#  'Besancon',
#  'Dijon',
#  'Annecy',
#  'Grenoble',
#  'Lyon',
#  'Gorges+du+Verdon',
#  'Bormes+les+Mimosas',
#  'Cassis',
#  'Marseille',
#  'Aix+en+Provence',
#  'Avignon',
#  'Uzes',
#  'Nimes',
#  'Aigues+Mortes',
#  'Saintes+Maries+de+la+mer',
#  'Collioure',
#  'Carcassonne',
#  'Ariege',
#  'Toulouse',
#  'Montauban',
#  'Biarritz',
#  'Bayonne',
#  'La+Rochelle']

# %%
# Nous récupérons les données GPS et les stockons dans deux listes distinctes
lat_list, lon_list = [], []
for city in cities_for_api: 
    r = requests.get(f'https://nominatim.openstreetmap.org/search?city={city}&country=France&format=json')
    lat_list.append(float(r.json()[0]['lat']))
    lon_list.append(float(r.json()[0]['lon']))

# %%
print(lat_list)
print(lon_list)
# Out:
# [48.6359541, 48.649518, 49.2764624, 49.4938975, 49.4404591, 48.8588897, 49.8941708, 50.6365654, 48.584614, 48.2495226, 48.0777517, 48.0447968, 47.2380222, 47.3215806, 45.8992348, 45.1875602, 45.7578137, 43.7496562, 43.1506968, 43.2140359, 43.2961743, 43.5298424, 43.9492493, 44.0121279, 43.8374249, 43.5661521, 43.4515922, 42.52505, 43.2130358, 42.9927428, 43.6044622, 44.0175835, 43.4832523, 43.4945144, 46.1591126]
# [-1.511459954959514, -2.0260409, -0.7024738, 0.1079732, 1.0939658, 2.3200410217200766, 2.2956951, 3.0635282, 7.7507127, 7.3454923, 7.3579641, 7.3079618, 6.0243622, 5.0414701, 6.1288847, 5.7357819, 4.8320114, 6.3285616, 6.3419285, 5.5396318, 5.3699525, 5.4474738, 4.8059012, 4.4196718, 4.3600687, 4.19154, 4.4277202, 3.0831554, 2.3491069, 1.6124975, 1.4442469, 1.3549991, -1.5592776, -1.4736657, -1.1520434]

# %%
type(lat_list[0])
# Out:
# float

# %% [markdown]
# ## API Openweather
#
# Nous utilisons l'API Openweather pour récupérer les données météorologiques des 35 villes.

# %%
# L'utilisation de cette API requiert une clé API
# (renseignez votre clé API ci-dessous :)
API_KEY = ''

# %% [markdown]
# ## Météo actuelle

# %%
# Nous effectuons un test pour Paris (qui se trouve à l'index 5)
lat_paris = lat_list[5]
lon_paris = lon_list[5]

# Météo actuelle pour Paris
r = requests.get(
    f'https://api.openweathermap.org/data/2.5/weather?lat={lat_paris}&lon={lon_paris}&appid={API_KEY}&units=metric&lang=fr'
)
print(r.content)
r.json()
# Out:
# b'{"coord":{"lon":2.32,"lat":48.8589},"weather":[{"id":501,"main":"Rain","description":"pluie mod\xc3\xa9r\xc3\xa9e","icon":"10n"},{"id":701,"main":"Mist","description":"brume","icon":"50n"}],"base":"stations","main":{"temp":10.84,"feels_like":10.49,"temp_min":10.19,"temp_max":11.32,"pressure":1005,"humidity":96},"visibility":5000,"wind":{"speed":7.2,"deg":210},"rain":{"1h":1.33},"clouds":{"all":100},"dt":1708556337,"sys":{"type":2,"id":2012208,"country":"FR","sunrise":1708498176,"sunset":1708535974},"timezone":3600,"id":6545270,"name":"Quartier du Palais-Royal","cod":200}'
# {'coord': {'lon': 2.32, 'lat': 48.8589},
#  'weather': [{'id': 501,
#    'main': 'Rain',
#    'description': 'pluie modérée',
#    'icon': '10n'},
#   {'id': 701, 'main': 'Mist', 'description': 'brume', 'icon': '50n'}],
#  'base': 'stations',
#  'main': {'temp': 10.84,
#   'feels_like': 10.49,
#   'temp_min': 10.19,
#   'temp_max': 11.32,
#   'pressure': 1005,
#   'humidity': 96},
#  'visibility': 5000,
#  'wind': {'speed': 7.2, 'deg': 210},
#  'rain': {'1h': 1.33},
#  'clouds': {'all': 100},
#  'dt': 1708556337,
#  'sys': {'type': 2,
#   'id': 2012208,
#   'country': 'FR',
#   'sunrise': 1708498176,
#   'sunset': 1708535974},
#  'timezone': 3600,
#  'id': 6545270,
#  'name': 'Quartier du Palais-Royal',
#  'cod': 200}

# %% [markdown]
# ## Prévisions
#
# Openweather donne gratuitement les prévisions météorologiques pour les 5 prochains jours, et par tranche de 3 heures.

# %%
# Prévisions météo pour les 5 prochains jours par tranche de 3 heures
r = requests.get(
    f'https://api.openweathermap.org/data/2.5/forecast?lat={lat_paris}&lon={lon_paris}&appid={API_KEY}&units=metric&lang=fr'
)
print(r.content)
r.json()
# Out:
# b'{"cod":"200","message":0,"cnt":40,"list":[{"dt":1708560000,"main":{"temp":10.84,"feels_like":10.49,"temp_min":10.84,"temp_max":11.33,"pressure":1005,"sea_level":1005,"grnd_level":1000,"humidity":96,"temp_kf":-0.49},"weather":[{"id":500,"main":"Rain","description":"l\xc3\xa9g\xc3\xa8re pluie","icon":"10n"}],"clouds":{"all":100},"wind":{"speed":5.47,"deg":218,"gust":13.5},"visibility":10000,"pop":1,"rain":{"3h":2.75},"sys":{"pod":"n"},"dt_txt":"2024-02-22 00:00:00"},{"dt":1708570800,"main":{"temp":11.16,"feels_like":10.81,"temp_min":11.16,"temp_max":11.8,"pressure":1004,"sea_level":1004,"grnd_level":997,"humidity":95,"temp_kf":-0.64},"weather":[{"id":500,"main":"Rain","description":"l\xc3\xa9g\xc3\xa8re pluie","icon":"10n"}],"clouds":{"all":100},"wind":{"speed":4.36,"deg":226,"gust":11.49},"visibility":10000,"pop":1,"rain":{"3h":1.7},"sys":{"pod":"n"},"dt_txt":"2024-02-22 03:00:00"},{"dt":1708581600,"main":{"temp":11.79,"feels_like":11.45,"temp_min":11.79,"temp_max":12.26,"pressure":1000,"sea_level":1000,"grnd_level":993,"humidity":93,"temp_kf":-0.47},"weather":[{"id":500,"main":"Rain","description":"l\xc3\xa9g\xc3\xa8re pluie","icon":"10n"}],"clouds":{"all":100},"wind":{"speed":6.05,"deg":210,"gust":13.3},"visibility":10000,"pop":1,"rain":{"3h":1.14},"sys":{"pod":"n"},"dt_txt":"2024-02-22 06:00:00"},{"dt":1708592400,"main":{"temp":12.27,"feels_like":11.82,"temp_min":12.27,"temp_max":12.27,"pressure":995,"sea_level":995,"grnd_level":990,"humidity":87,"temp_kf":0},"weather":[{"id":500,"main":"Rain","description":"l\xc3\xa9g\xc3\xa8re pluie","icon":"10d"}],"clouds":{"all":100},"wind":{"speed":8.79,"deg":207,"gust":17.85},"visibility":10000,"pop":1,"rain":{"3h":1.67},"sys":{"pod":"d"},"dt_txt":"2024-02-22 09:00:00"},{"dt":1708603200,"main":{"temp":12.09,"feels_like":11.55,"temp_min":12.09,"temp_max":12.09,"pressure":989,"sea_level":989,"grnd_level":984,"humidity":84,"temp_kf":0},"weather":[{"id":500,"main":"Rain","description":"l\xc3\xa9g\xc3\xa8re pluie","icon":"10d"}],"clouds":{"all":100},"wind":{"speed":9.76,"deg":202,"gust":20.47},"visibility":10000,"pop":1,"rain":{"3h":0.94},"sys":{"pod":"d"},"dt_txt":"2024-02-22 12:00:00"},{"dt":1708614000,"main":{"temp":10.89,"feels_like":9.89,"temp_min":10.89,"temp_max":10.89,"pressure":988,"sea_level":988,"grnd_level":983,"humidity":71,"temp_kf":0},"weather":[{"id":501,"main":"Rain","description":"pluie mod\xc3\xa9r\xc3\xa9e","icon":"10d"}],"clouds":{"all":100},"wind":{"speed":9.86,"deg":235,"gust":20.26},"visibility":10000,"pop":1,"rain":{"3h":4.58},"sys":{"pod":"d"},"dt_txt":"2024-02-22 15:00:00"},{"dt":1708624800,"main":{"temp":7.53,"feels_like":3.63,"temp_min":7.53,"temp_max":7.53,"pressure":995,"sea_level":995,"grnd_level":990,"humidity":68,"temp_kf":0},"weather":[{"id":500,"main":"Rain","description":"l\xc3\xa9g\xc3\xa8re pluie","icon":"10n"}],"clouds":{"all":91},"wind":{"speed":7.42,"deg":264,"gust":15.3},"visibility":10000,"pop":1,"rain":{"3h":0.44},"sys":{"pod":"n"},"dt_txt":"2024-02-22 18:00:00"},{"dt":1708635600,"main":{"temp":6.48,"feels_like":2.34,"temp_min":6.48,"temp_max":6.48,"pressure":998,"sea_level":998,"grnd_level":993,"humidity":70,"temp_kf":0},"weather":[{"id":500,"main":"Rain","description":"l\xc3\xa9g\xc3\xa8re pluie","icon":"10n"}],"clouds":{"all":100},"wind":{"speed":7.24,"deg":247,"gust":14.18},"visibility":10000,"pop":0.92,"rain":{"3h":0.5},"sys":{"pod":"n"},"dt_txt":"2024-02-22 21:00:00"},{"dt":1708646400,"main":{"temp":5.18,"feels_like":0.95,"temp_min":5.18,"temp_max":5.18,"pressure":999,"sea_level":999,"grnd_level":994,"humidity":74,"temp_kf":0},"weather":[{"id":803,"main":"Clouds","description":"nuageux","icon":"04n"}],"clouds":{"all":55},"wind":{"speed":6.45,"deg":226,"gust":13.45},"visibility":10000,"pop":0.66,"sys":{"pod":"n"},"dt_txt":"2024-02-23 00:00:00"},{"dt":1708657200,"main":{"temp":4.86,"feels_like":0.59,"temp_min":4.86,"temp_max":4.86,"pressure":998,"sea_level":998,"grnd_level":993,"humidity":79,"temp_kf":0},"weather":[{"id":802,"main":"Clouds" ...
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1708560000,
#    'main': {'temp': 10.84,
#     'feels_like': 10.49,
#     'temp_min': 10.84,
#     'temp_max': 11.33,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 1000,
#     'humidity': 96,
#     'temp_kf': -0.49},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'légère pluie',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.47, 'deg': 218, 'gust': 13.5},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 2.75},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-22 00:00:00'},
#   {'dt': 1708570800,
#    'main': {'temp': 11.16,
#     'feels_like': 10.81,
#     'temp_min': 11.16,
#     'temp_max': 11.8,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 997,
#     'humidity': 95,
#     'temp_kf': -0.64},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'légère pluie',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.36, 'deg': 226, 'gust': 11.49},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.7},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-22 03:00:00'},
#   {'dt': 1708581600,
#    'main': {'temp': 11.79,
#     'feels_like': 11.45,
#     'temp_min': 11.79,
#     'temp_max': 12.26,
#     'pressure': 1000,
#     'sea_level': 1000,
#     'grnd_level': 993,
#     'humidity': 93,
#     'temp_kf': -0.47},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'légère pluie',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.05, 'deg': 210, 'gust': 13.3},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.14},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-22 06:00:00'},
#   {'dt': 1708592400,
#    'main': {'temp': 12.27,
#     'feels_like': 11.82,
#     'temp_min': 12.27,
#     'temp_max': 12.27,
#     'pressure': 995,
#     'sea_level': 995,
#     'grnd_level': 990,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'légère pluie',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 8.79, 'deg': 207, 'gust': 17.85},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.67},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-22 09:00:00'},
#   {'dt': 1708603200,
#    'main': {'temp': 12.09,
#     'feels_like': 11.55,
#     'temp_min': 12.09,
#     'temp_max': 12.09,
#     'pressure': 989,
#     'sea_level': 989,
#     'grnd_level': 984,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'légère pluie',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 9.76, 'deg': 202, 'gust': 20.47},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.94},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-22 12:00:00'},
#   {'dt': 1708614000,
#    'main': {'temp': 10.89,
#     'feels_like': 9.89,
#     'temp_min': 10.89,
#     'temp_max': 10.89,
#     'pressure': 988,
#     'sea_level': 988,
#     'grnd_level': 983,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'pluie modérée',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 9.86, 'deg': 235, 'gust': 20.26},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 4.58},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-22 15:00:00'},
#   {'dt': 1708624800,
#    'main': {'temp': 7.53,
#     'feels_like': 3.63,
#     'temp_min': 7.53,
#     'temp_max': 7.53,
#     'pressure': 995,
#     'sea_level': 995,
#     'grnd_level': 990,
#     'humidity': 68,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'légère pluie',
#      'icon': '10n'}],
#    'clouds': {'all': 91},
#    'wind': {'speed': 7.42, 'deg': 264, 'gust': 15.3},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.44},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-22 18:00:00'},
#   {'dt': 1708635600,
#    'main': {'temp': 6.48,
#     'feels_like': 2.34,
#     'temp_min': 6.48,
#     'temp_max': 6.48,
#     'pressure': 998,
#     'sea_level': 998,
#     'grnd_level': 993,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'légère pluie',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.24, 'deg': 247, 'gust': 14.18},
#    'visibility': 10000,
#    'pop': 0.92,
#    'rain': {'3h': 0.5},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-22 21:00:00'},
#   {'dt': 1708646400,
#    'main': {'temp': 5.18,
#     'feels_like': 0.95,
#     'temp_min': 5.18,
#     'temp_max': 5.18,
#     'pressure': 999,
#     'sea_level': 999,
#     'grnd_level': 994,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nuageux',
#      'icon': '04n'}],
#    'clouds': {'all': 55},
#    'wind': {'speed': 6.45, 'deg': 226, 'gust': 13.45},
#    'visibility': 10000,
#    'pop': 0.66,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-23 00:00:00'},
#   {'dt': 1708657200,
#    'main': {'temp': 4.86,
#     'feels_like': 0.59,
#     'temp_min': 4.86,
#     'temp_max': 4.86,
#     'pressure': 998,
#     'sea_level': 998,
#     'grnd_level': 993,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'partiellement nuageux',
#      'icon': '03n'}],
#    'clouds': {'all': 48},
#    'wind': {'speed': 6.33, 'deg': 215, 'gust': 12.58},
#    'visibility': 10000,
#    'pop': 0.05,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-23 03:00:00'},
#   {'dt': 1708668000,
#    'main': {'temp': 4.63,
#     'feels_like': 0.39,
#     'temp_min': 4.63,
#     'temp_max': 4.63,
#     'pressure': 997,
#     'sea_level': 997,
#     'grnd_level': 992,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'partiellement nuageux',
#      'icon': '03n'}],
#    'clouds': {'all': 27},
#    'wind': {'speed': 6.09, 'deg': 210, 'gust': 12.66},
#    'visibility': 10000,
#    'pop': 0.02,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-23 06:00:00'},
#   {'dt': 1708678800,
#    'main': {'temp': 5.8,
#     'feels_like': 1.95,
#     'temp_min': 5.8,
#     'temp_max': 5.8,
#     'pressure': 997,
#     'sea_level': 997,
#     'grnd_level': 992,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'partiellement nuageux',
#      'icon': '03d'}],
#    'clouds': {'all': 47},
#    'wind': {'speed': 5.9, 'deg': 208, 'gust': 11.74},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-23 09:00:00'},
#   {'dt': 1708689600,
#    'main': {'temp': 8.81,
#     'feels_like': 5.54,
#     'temp_min': 8.81,
#     'temp_max': 8.81,
#     'pressure': 996,
#     'sea_level': 996,
#     'grnd_level': 991,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'légère pluie',
#      'icon': '10d'}],
#    'clouds': {'all': 59},
#    'wind': {'speed': 6.59, 'deg': 224, 'gust': 10.24},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.37},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-23 12:00:00'},
#   {'dt': 1708700400,
#    'main': {'temp': 6.49,
#     'feels_like': 3.01,
#     'temp_min': 6.49,
#     'temp_max': 6.49,
#     'pressure': 995,
#     'sea_level': 995,
#     'grnd_level': 990,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'légère pluie',
#      'icon': '10d'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 5.44, 'deg': 220, 'gust': 9.43},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-23 15:00:00'},
#   {'dt': 1708711200,
#    'main': {'temp': 5.99,
#     'feels_like': 2.76,
#     'temp_min': 5.99,
#     'temp_max': 5.99,
#     'pressure': 996,
#     'sea_level': 996,
#     'grnd_level': 990,
#     'humidity': 65,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'légère pluie',
#      'icon': '10n'}],
#    'clouds': {'all': 85},
#    'wind': {'speed': 4.61, 'deg': 226, 'gust': 9.17},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.53},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-23 18:00:00'},
#   {'dt': 1708722000,
#    'main': {'temp': 5.09,
#     'feels_like': 1.9,
#     'temp_min': 5.09,
#     'temp_max': 5.09,
#     'pressure': 996,
#     'sea_level': 996,
#     'grnd_level': 991,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'couvert',
#      'icon': '04n'}],
#    'clouds': {'all': 91},
#    'wind': {'speed': 4.13, 'deg': 215, 'gust': 9.27},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-23 21:00:00'},
#   {'dt': 1708732800,
#    'main': {'temp': 3.95,
#     'feels_like': 0.56,
#     'temp_min': 3.95,
#     'temp_max': 3.95,
#     'pressure': 997,
#     'sea_level': 997,
#     'grnd_level': 992,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'couvert',
#      'icon': '04n'}],
#    'clouds': {'all': 87},
#    'wind': {'speed': 4.02, 'deg': 214, 'gust': 8.48},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-24 00:00:00'},
#   {'dt': 1708743600,
#    'main': {'temp': 2.9,
#     'feels_like': -1.11,
#     'temp_min': 2.9,
#     'temp_max': 2.9,
#     'pressure': 998,
#     'sea_level': 998,
#     'grnd_level': 993,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nuageux',
#      'icon': '04n'}],
#    'clouds': {'all': 53},
#    'wind': {'speed': 4.67, 'deg': 213, 'gust': 10.65},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-24 03:00:00'},
#   {'dt': 1708754400,
#    'main': {'temp': 2.4,
#     'feels_like': -1.74,
#     'temp_min': 2.4,
#     'temp_max': 2.4,
#     'pressure': 999,
#     'sea_level': 999,
#     'grnd_level': 994,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'partiellement nuageux',
#      'icon': '03n'}],
#    'clouds': {'all': 47},
#    'wind': {'speed': 4.67, 'deg': 201, 'gust': 11.61},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-24 06:00:00'},
#   {'dt': 1708765200,
#    'main': {'temp': 4.02,
#     'feels_like': -0.04,
#     'temp_min': 4.02,
#     'temp_max': 4.02,
#     'pressure': 1000,
#     'sea_level': 1000,
#     'grnd_level': 995,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'partiellement nuageux',
#      'icon': '03d'}],
#    'clouds': {'all': 50},
#    'wind': {'speed': 5.32, 'deg': 195, 'gust': 11.34},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-24 09:00:00'},
#   {'dt': 1708776000,
#    'main': {'temp': 8.51,
#     'feels_like': 5.21,
#     'temp_min': 8.51,
#     'temp_max': 8.51,
#     'pressure': 1000,
#     'sea_level': 1000,
#     'grnd_level': 995,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'partiellement nuageux',
#      'icon': '03d'}],
#    'clouds': {'all': 32},
#    'wind': {'speed': 6.43, 'deg': 202, 'gust': 10.04},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-24 12:00:00'},
#   {'dt': 1708786800,
#    'main': {'temp': 9.29,
#     'feels_like': 6.26,
#     'temp_min': 9.29,
#     'temp_max': 9.29,
#     'pressure': 999,
#     'sea_level': 999,
#     'grnd_level': 994,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'légère pluie',
#      'icon': '10d'}],
#    'clouds': {'all': 76},
#    'wind': {'speed': 6.23, 'deg': 199, 'gust': 10.63},
#    'visibility': 10000,
#    'pop': 0.84,
#    'rain': {'3h': 0.35},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-24 15:00:00'},
#   {'dt': 1708797600,
#    'main': {'temp': 7.01,
#     'feels_like': 3.67,
#     'temp_min': 7.01,
#     'temp_max': 7.01,
#     'pressure': 1000,
#     'sea_level': 1000,
#     'grnd_level': 995,
#     'humidity': 77,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'légère pluie',
#      'icon': '10n'}],
#    'clouds': {'all': 88},
#    'wind': {'speed': 5.44, 'deg': 211, 'gust': 9.8},
#    'visibility': 10000,
#    'pop': 0.97,
#    'rain': {'3h': 1.59},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-24 18:00:00'},
#   {'dt': 1708808400,
#    'main': {'temp': 5.95,
#     'feels_like': 2.56,
#     'temp_min': 5.95,
#     'temp_max': 5.95,
#     'pressure': 1001,
#     'sea_level': 1001,
#     'grnd_level': 996,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'légère pluie',
#      'icon': '10n'}],
#    'clouds': {'all': 78},
#    'wind': {'speed': 4.92, 'deg': 221, 'gust': 10.9},
#    'visibility': 10000,
#    'pop': 0.55,
#    'rain': {'3h': 0.25},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-24 21:00:00'},
#   {'dt': 1708819200,
#    'main': {'temp': 5.1,
#     'feels_like': 1.76,
#     'temp_min': 5.1,
#     'temp_max': 5.1,
#     'pressure': 1002,
#     'sea_level': 1002,
#     'grnd_level': 997,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'légère pluie',
#      'icon': '10n'}],
#    'clouds': {'all': 60},
#    'wind': {'speed': 4.41, 'deg': 229, 'gust': 10.63},
#    'visibility': 10000,
#    'pop': 0.36,
#    'rain': {'3h': 0.11},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-25 00:00:00'},
#   {'dt': 1708830000,
#    'main': {'temp': 4.15,
#     'feels_like': 0.94,
#     'temp_min': 4.15,
#     'temp_max': 4.15,
#     'pressure': 1002,
#     'sea_level': 1002,
#     'grnd_level': 996,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nuageux',
#      'icon': '04n'}],
#    'clouds': {'all': 67},
#    'wind': {'speed': 3.8, 'deg': 204, 'gust': 9.7},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-25 03:00:00'},
#   {'dt': 1708840800,
#    'main': {'temp': 3.76,
#     'feels_like': 0.51,
#     'temp_min': 3.76,
#     'temp_max': 3.76,
#     'pressure': 1001,
#     'sea_level': 1001,
#     'grnd_level': 995,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'nuageux',
#      'icon': '04n'}],
#    'clouds': {'all': 81},
#    'wind': {'speed': 3.72, 'deg': 180, 'gust': 10.86},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-25 06:00:00'},
#   {'dt': 1708851600,
#    'main': {'temp': 5.25,
#     'feels_like': 1.69,
#     'temp_min': 5.25,
#     'temp_max': 5.25,
#     'pressure': 998,
#     'sea_level': 998,
#     'grnd_level': 993,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'couvert',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.92, 'deg': 155, 'gust': 11.89},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-25 09:00:00'},
#   {'dt': 1708862400,
#    'main': {'temp': 7.4,
#     'feels_like': 3.58,
#     'temp_min': 7.4,
#     'temp_max': 7.4,
#     'pressure': 993,
#     'sea_level': 993,
#     'grnd_level': 988,
#     'humidity': 75,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'couvert',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.04, 'deg': 149, 'gust': 13.8},
#    'visibility': 10000,
#    'pop': 0.14,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-25 12:00:00'},
#   {'dt': 1708873200,
#    'main': {'temp': 5.8,
#     'feels_like': 1.15,
#     'temp_min': 5.8,
#     'temp_max': 5.8,
#     'pressure': 987,
#     'sea_level': 987,
#     'grnd_level': 982,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'légère pluie',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 8.22, 'deg': 144, 'gust': 16.03},
#    'visibility': 9236,
#    'pop': 0.95,
#    'rain': {'3h': 2.23},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-25 15:00:00'},
#   {'dt': 1708884000,
#    'main': {'temp': 7.61,
#     'feels_like': 4.07,
#     'temp_min': 7.61,
#     'temp_max': 7.61,
#     'pressure': 981,
#     'sea_level': 981,
#     'grnd_level': 976,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'pluie modérée',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.4, 'deg': 159, 'gust': 15.63},
#    'visibility': 7549,
#    'pop': 1,
#    'rain': {'3h': 6.77},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-25 18:00:00'},
#   {'dt': 1708894800,
#    'main': {'temp': 9.97,
#     'feels_like': 6.61,
#     'temp_min': 9.97,
#     'temp_max': 9.97,
#     'pressure': 982,
#     'sea_level': 982,
#     'grnd_level': 977,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'pluie modérée',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 8.1, 'deg': 209, 'gust': 15.75},
#    'visibility': 10000,
#    'pop': 0.94,
#    'rain': {'3h': 4.93},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-25 21:00:00'},
#   {'dt': 1708905600,
#    'main': {'temp': 8.96,
#     'feels_like': 5.64,
#     'temp_min': 8.96,
#     'temp_max': 8.96,
#     'pressure': 985,
#     'sea_level': 985,
#     'grnd_level': 980,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'couvert',
#      'icon': '04n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 6.88, 'deg': 193, 'gust': 14.01},
#    'visibility': 10000,
#    'pop': 0.74,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-26 00:00:00'},
#   {'dt': 1708916400,
#    'main': {'temp': 8.18,
#     'feels_like': 4.57,
#     'temp_min': 8.18,
#     'temp_max': 8.18,
#     'pressure': 984,
#     'sea_level': 984,
#     'grnd_level': 979,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'couvert',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.1, 'deg': 161, 'gust': 16.19},
#    'visibility': 10000,
#    'pop': 0.03,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-26 03:00:00'},
#   {'dt': 1708927200,
#    'main': {'temp': 7.85,
#     'feels_like': 3.89,
#     'temp_min': 7.85,
#     'temp_max': 7.85,
#     'pressure': 981,
#     'sea_level': 981,
#     'grnd_level': 976,
#     'humidity': 75,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'légère pluie',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.94, 'deg': 152, 'gust': 18.13},
#    'visibility': 10000,
#    'pop': 0.6,
#    'rain': {'3h': 0.88},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-26 06:00:00'},
#   {'dt': 1708938000,
#    'main': {'temp': 6.94,
#     'feels_like': 3.02,
#     'temp_min': 6.94,
#     'temp_max': 6.94,
#     'pressure': 983,
#     'sea_level': 983,
#     'grnd_level': 978,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'pluie modérée',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.96, 'deg': 143, 'gust': 13.41},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 5.84},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-26 09:00:00'},
#   {'dt': 1708948800,
#    'main': {'temp': 7.02,
#     'feels_like': 3.65,
#     'temp_min': 7.02,
#     'temp_max': 7.02,
#     'pressure': 985,
#     'sea_level': 985,
#     'grnd_level': 980,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'légère pluie',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.51, 'deg': 137, 'gust': 10.53},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.85},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-26 12:00:00'},
#   {'dt': 1708959600,
#    'main': {'temp': 7.17,
#     'feels_like': 4.14,
#     'temp_min': 7.17,
#     'temp_max': 7.17,
#     'pressure': 987,
#     'sea_level': 987,
#     'grnd_level': 982,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'légère pluie',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.79, 'deg': 124, 'gust': 8.42},
#    'visibility': 10000,
#    'pop': 0.97,
#    'rain': {'3h': 1.87},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-26 15:00:00'},
#   {'dt': 1708970400,
#    'main': {'temp': 7.27,
#     'feels_like': 4.65,
#     'temp_min': 7.27,
#     'temp_max': 7.27,
#     'pressure': 990,
#     'sea_level': 990,
#     'grnd_level': 985,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'légère pluie',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4, 'deg': 103, 'gust': 6.79},
#    'visibility': 10000,
#    'pop': 0.99,
#    'rain': {'3h': 0.54},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-26 18:00:00'},
#   {'dt': 1708981200,
#    'main': {'temp': 6.88,
#     'feels_like': 3.87,
#     'temp_min': 6.88,
#     'temp_max': 6.88,
#     'pressure': 994,
#     'sea_level': 994,
#     'grnd_level': 989,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'légère pluie',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.6, 'deg': 77, 'gust': 7.92},
#    'visibility': 10000,
#    'pop': 0.91,
#    'rain': {'3h': 0.66},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-26 21:00:00'}],
#  'city': {'id': 6545270,
#   'name': 'Quartier du Palais-Royal',
#   'coord': {'lat': 48.8589, 'lon': 2.32},
#   'country': 'FR',
#   'population': 0,
#   'timezone': 3600,
#   'sunrise': 1708498176,
#   'sunset': 1708535974}}

# %% [markdown]
# Le résultat de la requête contient 40 éléments et non 5 parce que les prévisions sont données par tranche de 3 heures.
#
# Afin de récupérer la prévision de demain (soit dans 24 heures) nous devons sélectionner l'élément à l'index 7 :
# --> 24 heures = 3 heures x 8 (auquel nous retirons 1 car l'index commence à 0)
#
# Voici les index qui permettent de récupérer les prévisions pour les 5 prochains jours :
#
# - Prévision dans 1 jour :  7
#
# - Prévisions dans 2 jours : 15
#
# - Prévisions dans 3 jours : 23
#
# - Prévisions dans 4 jours : 31
#
# - Prévisions dans 5 jours : 39

# %%
# Nous vérifions que la prévision à l'index 39 nous retourne bien la prévision dans 5 jours
r.json()['list'][39]
# Out:
# {'dt': 1708981200,
#  'main': {'temp': 6.88,
#   'feels_like': 3.87,
#   'temp_min': 6.88,
#   'temp_max': 6.88,
#   'pressure': 994,
#   'sea_level': 994,
#   'grnd_level': 989,
#   'humidity': 86,
#   'temp_kf': 0},
#  'weather': [{'id': 500,
#    'main': 'Rain',
#    'description': 'légère pluie',
#    'icon': '10n'}],
#  'clouds': {'all': 100},
#  'wind': {'speed': 4.6, 'deg': 77, 'gust': 7.92},
#  'visibility': 10000,
#  'pop': 0.91,
#  'rain': {'3h': 0.66},
#  'sys': {'pod': 'n'},
#  'dt_txt': '2024-02-26 21:00:00'}

# %% [markdown]
# ## Sélection et récupération des données

# %% [markdown]
# Nous identifions 8 données météorologiques intéressantes pour notre projet :
#
# 1. *list.main.temp* : la température
#
# 2. *list.weather.main* : la description générale (nuageux, pluie, etc.)
#
# 3. *list.clouds.all* : le taux de nuages
#
# 4. *list.wind.speed* : la vitesse du vent
#
# 5. *list.pop* : la probabilité de pleuvoir
#
# 6. *list.rain.3h* : le volume de précipitations cumulées pendant les 3 dernières heures
#
# 7. *list.main.humidity* : le taux d'humidité

# %%
temp = r.json()['list'][7]['main']['temp']
weather = r.json()['list'][7]['weather'][0]['main']
description = r.json()['list'][7]['weather'][0]['description']
clouds = r.json()['list'][7]['clouds']['all']
wind = r.json()['list'][7]['wind']['speed']
pop = r.json()['list'][7]['pop']
try:
    rain = r.json()['list'][7]['rain']['3h']
except: 
    print('No rain data for selected time')
humidity = r.json()['list'][7]['main']['humidity']

# %%
# Nous préparons des listes pour stocker les données récupérées

temp_d1, weather_d1, clouds_d1, pop_d1, rain_d1, wind_d1, humidity_d1 = [], [], [], [], [], [], []
temp_d2, weather_d2, clouds_d2, pop_d2, rain_d2, wind_d2, humidity_d2 = [], [], [], [], [], [], []
temp_d3, weather_d3, clouds_d3, pop_d3, rain_d3, wind_d3, humidity_d3 = [], [], [], [], [], [], []
temp_d4, weather_d4, clouds_d4, pop_d4, rain_d4, wind_d4, humidity_d4 = [], [], [], [], [], [], []
temp_d5, weather_d5, clouds_d5, pop_d5, rain_d5, wind_d5, humidity_d5 = [], [], [], [], [], [], []

# %%
# Nous construisons une fonction qui permet de récupérer ces données depuis l'API Openweather

def extractWeatherForecast(temp, weather, clouds, wind, humidity, pop, rain, fi): # fi : forecast index
    ''' This function collects the data from Openweather API '''
    for lat, lon in zip(lat_list, lon_list):
        r = requests.get(
            f'https://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={API_KEY}&units=metric&lang=fr'
        )
        temp.append(r.json()['list'][fi]['main']['temp'])
        weather.append(r.json()['list'][fi]['weather'][0]['main'])
        clouds.append(r.json()['list'][fi]['clouds']['all'])
        wind.append(r.json()['list'][fi]['wind']['speed'])
        humidity.append(r.json()['list'][fi]['main']['humidity'])
        pop.append(r.json()['list'][fi]['pop'])
        try:
            rain.append(r.json()['list'][fi]['rain']['3h'])
        except: 
            rain.append(0)

# %%
# Application de la fonction

extractWeatherForecast(temp_d1, weather_d1, clouds_d1, wind_d1, humidity_d1, pop_d1, rain_d1, fi=7)
extractWeatherForecast(temp_d2, weather_d2, clouds_d2, wind_d2, humidity_d2, pop_d2, rain_d2, fi=15)
extractWeatherForecast(temp_d3, weather_d3, clouds_d3, wind_d3, humidity_d3, pop_d3, rain_d3, fi=23)
extractWeatherForecast(temp_d4, weather_d4, clouds_d4, wind_d4, humidity_d4, pop_d4, rain_d4, fi=31)
extractWeatherForecast(temp_d5, weather_d5, clouds_d5, wind_d5, humidity_d5, pop_d5, rain_d5, fi=39)

# %%
# Vérification des données de température des 5 prochains jours

print(temp_d1)
print(temp_d2)
print(temp_d3)
print(temp_d4)
print(temp_d5)
# Out:
# [5.38, 5.78, 4.95, 6.73, 4.92, 6.48, 6.04, 6.05, 8.56, 4.53, 7.9, 7.75, 6.35, 5.88, 7.46, 9.01, 8.67, 7.28, 13.11, 13.84, 13.96, 12.02, 12.02, 10.21, 10.96, 12.29, 12.68, 10.36, 7.63, 6.21, 7.28, 7.48, 9.47, 9.23, 8.87]
# [2.99, 4.28, 2.65, 4.76, 2.52, 5.09, 2.92, 3.84, 5.18, 1.77, 5.18, 5.22, 3.96, 2.82, 3.39, 4.77, 5.3, 0.05, 9.16, 10.15, 10.31, 6.9, 6.78, 5.91, 6.84, 8.62, 9.11, 7.67, 6.18, 4.27, 5.45, 4.58, 7.5, 7.01, 5.97]
# [5.53, 6.57, 4.61, 7.54, 4.39, 5.95, 4.36, 5.09, 3.25, -0.91, 2.34, 2.3, 3.36, 3.82, 0.94, 2.86, 6.2, -0.15, 8.34, 9.17, 9.32, 5.86, 5.99, 5.64, 6.98, 8.73, 8.79, 7.13, 7.01, 4.97, 5.84, 5.44, 8.46, 8.18, 8.88]
# [7.67, 7.79, 7.9, 9.25, 8.97, 9.97, 9.06, 4.44, 6.36, 2.09, 5.07, 4.81, 9.14, 6.88, 4.19, 6.64, 7.36, 2.88, 11.09, 12.11, 12.35, 8.04, 9.35, 8.34, 9.39, 11.42, 12.67, 8.63, 6.33, 8.87, 7.58, 8.6, 11.43, 11.25, 9.5]
# [6.77, 7.2, 7.48, 7.98, 6.79, 6.88, 7.32, 7.82, 6.06, 2.69, 6.32, 6.49, 5.96, 6.02, 3.79, 5.9, 7.02, 2.05, 9.7, 10.09, 10.26, 7.38, 8.01, 7.17, 8.08, 9.73, 10.01, 8, 7.2, 4.85, 6.02, 5.74, 9.61, 9.25, 7.85]

# %% [markdown]
# ## Création dataframe Pandas

# %%
# Nous créons un dictionnaire qui permettra de créer le dataframe

city_dict = {}

# %%
# Ajout des listes ville_id, ville, latitude et longitude à notre dictionnaire

city_dict['city_id'] = [i for i in range(1,36)]
city_dict['city'] = cities
city_dict['lat_city'] = lat_list
city_dict['lon_city'] = lon_list

# %%
# Ajout des données météorologiques dans notre dictionnaire

city_dict['temp_d1'] = temp_d1
city_dict['temp_d2'] = temp_d2
city_dict['temp_d3'] = temp_d3
city_dict['temp_d4'] = temp_d4
city_dict['temp_d5'] = temp_d5

city_dict['weather_d1'] = weather_d1
city_dict['weather_d2'] = weather_d2
city_dict['weather_d3'] = weather_d3
city_dict['weather_d4'] = weather_d4
city_dict['weather_d5'] = weather_d5

city_dict['clouds_d1'] = clouds_d1
city_dict['clouds_d2'] = clouds_d2
city_dict['clouds_d3'] = clouds_d3
city_dict['clouds_d4'] = clouds_d4
city_dict['clouds_d5'] = clouds_d5

city_dict['wind_d1'] = wind_d1
city_dict['wind_d2'] = wind_d2
city_dict['wind_d3'] = wind_d3
city_dict['wind_d4'] = wind_d4
city_dict['wind_d5'] = wind_d5

city_dict['humidity_d1'] = humidity_d1
city_dict['humidity_d2'] = humidity_d2
city_dict['humidity_d3'] = humidity_d3
city_dict['humidity_d4'] = humidity_d4
city_dict['humidity_d5'] = humidity_d5

city_dict['pop_d1'] = pop_d1
city_dict['pop_d2'] = pop_d2
city_dict['pop_d3'] = pop_d3
city_dict['pop_d4'] = pop_d4
city_dict['pop_d5'] = pop_d5

city_dict['rain_d1'] = rain_d1
city_dict['rain_d2'] = rain_d2
city_dict['rain_d3'] = rain_d3
city_dict['rain_d4'] = rain_d4
city_dict['rain_d5'] = rain_d5

# %%
dataset = pd.DataFrame().from_dict(city_dict)

# %%
dataset.shape
# Out:
# (35, 39)

# %% [markdown]
# ## Résultats

# %%
pd.set_option('display.max_columns', None)
dataset = pd.DataFrame().from_dict(city_dict)
dataset.head(35)
# Out:
#     city_id                          city   lat_city  lon_city  temp_d1  \
# 0         1             Mont Saint Michel  48.635954 -1.511460     5.38
# 1         2                       St Malo  48.649518 -2.026041     5.78
# 2         3                        Bayeux  49.276462 -0.702474     4.95
# 3         4                      Le Havre  49.493898  0.107973     6.73
# 4         5                         Rouen  49.440459  1.093966     4.92
# 5         6                         Paris  48.858890  2.320041     6.48
# 6         7                        Amiens  49.894171  2.295695     6.04
# 7         8                         Lille  50.636565  3.063528     6.05
# 8         9                    Strasbourg  48.584614  7.750713     8.56
# 9        10  Chateau du Haut Koenigsbourg  48.249523  7.345492     4.53
# 10       11                        Colmar  48.077752  7.357964     7.90
# 11       12                     Eguisheim  48.044797  7.307962     7.75
# 12       13                      Besancon  47.238022  6.024362     6.35
# 13       14                         Dijon  47.321581  5.041470     5.88
# 14       15                        Annecy  45.899235  6.128885     7.46
# 15       16                      Grenoble  45.187560  5.735782     9.01
# 16       17                          Lyon  45.757814  4.832011     8.67
# 17       18              Gorges du Verdon  43.749656  6.328562     7.28
# 18       19            Bormes les Mimosas  43.150697  6.341928    13.11
# 19       20                        Cassis  43.214036  5.539632    13.84
# 20       21                     Marseille  43.296174  5.369953    13.96
# 21       22               Aix en Provence  43.529842  5.447474    12.02
# 22       23                       Avignon  43.949249  4.805901    12.02
# 23       24                          Uzes  44.012128  4.419672    10.21
# 24       25                         Nimes  43.837425  4.360069    10.96
# 25       26                 Aigues Mortes  43.566152  4.191540    12.29
# 26       27      Saintes Maries de la mer  43.451592  4.427720    12.68
# 27       28                     Collioure  42.525050  3.083155    10.36
# 28       29                   Carcassonne  43.213036  2.349107     7.63
# 29       30                        Ariege  42.992743  1.612497     6.21
# 30       31                      Toulouse  43.604462  1.444247     7.28
# 31       32                     Montauban  44.017584  1.354999     7.48
# 32       33                      Biarritz  43.483252 -1.559278     9.47
# 33       34                       Bayonne  43.494514 -1.473666     9.23
# 34       35                   La Rochelle  46.159113 -1.152043     8.87
#
#     temp_d2  temp_d3  temp_d4  temp_d5 weather_d1 weather_d2 weather_d3  \
# 0      2.99     5.53     7.67     6.77       Rain       Rain       Rain
# 1      4.28     6.57     7.79     7.20       Rain       Rain       Rain
# 2      2.65     4.61     7.90     7.48       Rain       Rain       Rain
# 3      4.76     7.54     9.25     7.98       Rain       Rain       Rain
# 4      2.52     4.39     8.97     6.79       Rain     Clouds       Rain
# 5      5.09     5.95     9.97     6.88       Rain     Clouds       Rain
# 6      2.92     4.36     9.06     7.32       Rain     Clouds       Rain
# 7      3.84     5.09     4.44     7.82       Rain       Rain       Rain
# 8      5.18     3.25     6.36     6.06       Rain     Clouds      Clear
# 9      1.77    -0.91     2.09     2.69       Rain     Clouds      Clear
# 10     5.18     2.34     5.07     6.32       Rain     Clouds      Clear
# 11     5.22     2.30     4.81     6.49       Rain     Clouds     Clouds
# 12     3.96     3.36     9.14     5.96       Rain       Rain     Clouds
# 13     2.82     3.82     6.88     6.02       Rain     Clouds     Clouds
# 14     3.39     0.94     4.19     3.79       Rain       Snow     Clouds
# 15     4.77     2.86     6.64     5.90       Rain       Snow     Clouds
# 16     5.30     6.20     7.36     7.02       Rain     Clouds     Clouds
# 17     0.05    -0.15     2.88     2.05       Rain     Clouds      Clear
# 18     9.16     8.34    11.09     9.70       Rain     Clouds      Clear
# 19    10.15     9.17    12.11    10.09       Rain     Clouds      Clear
# 20    10.31     9.32    12.35    10.26       Rain     Clouds      Clear
# 21     6.90     5.86     8.04     7.38       Rain     Clouds      Clear
# 22     6.78     5.99     9.35     8.01       Rain     Clouds     Clouds
# 23     5.91     5.64     8.34     7.17       Rain     Clouds     Clouds
# 24     6.84     6.98     9.39     8.08       Rain     Clouds     Clouds
# 25     8.62     8.73    11.42     9.73       Rain     Clouds     Clouds
# 26     9.11     8.79    12.67    10.01       Rain     Clouds     Clouds
# 27     7.67     7.13     8.63     8.00     Clouds       Rain     Clouds
# 28     6.18     7.01     6.33     7.20       Rain       Rain       Rain
# 29     4.27     4.97     8.87     4.85       Rain       Rain       Rain
# 30     5.45     5.84     7.58     6.02       Rain       Rain       Rain
# 31     4.58     5.44     8.60     5.74       Rain       Rain       Rain
# 32     7.50     8.46    11.43     9.61       Rain       Rain       Rain
# 33     7.01     8.18    11.25     9.25       Rain       Rain       Rain
# 34     5.97     8.88     9.50     7.85       Rain       Rain       Rain
#
#    weather_d4 weather_d5  clouds_d1  clouds_d2  clouds_d3  clouds_d4  \
# 0        Rain       Rain         47         83         99         84
# 1      Clouds       Rain         63         75        100         82
# 2        Rain       Rain         53         64         40         99
# 3        Rain       Rain         47         82         42        100
# 4        Rain       Rain         70         49         82        100
# 5        Rain       Rain        100         91         78        100
# 6        Rain       Rain         96         50         93        100
# 7        Rain       Rain         96         73        100        100
# 8        Rain     Clouds        100         84          3        100
# 9        Rain     Clouds        100         88          7        100
# 10       Rain       Rain        100         94         10        100
# 11       Rain       Rain        100         97         11        100
# 12       Rain       Rain        100         72         64        100
# 13       Rain       Rain        100         98         96        100
# 14       Rain       Rain        100        100         67        100
# 15       Rain       Rain        100         97         26        100
# 16       Rain       Rain        100        100        100        100
# 17       Rain       Rain        100         48          6        100
# 18       Rain       Rain        100         40          2        100
# 19       Rain       Rain        100         23          1        100
# 20       Rain     Clouds        100         15          1        100
# 21       Rain     Clouds        100         20          4        100
# 22       Rain     Clouds        100         93         56        100
# 23       Rain     Clouds        100        100         71        100
# 24     Clouds     Clouds        100         99         79        100
# 25     Clouds     Clouds        100         78         78        100
# 26     Clouds     Clouds        100         42         66        100
# 27     Clouds       Rain         75         89         29         56
# 28     Clouds     Clouds         99         88         97         82
# 29       Rain     Clouds        100         97        100         87
# 30       Rain     Clouds        100        100        100         97
# 31       Rain       Rain        100        100         98        100
# 32       Rain       Rain        100        100        100        100
# 33       Rain       Rain        100        100        100        100
# 34       Rain       Rain         17         99        100         64
#
#     clouds_d5  wind_d1  wind_d2  wind_d3  wind_d4  wind_d5  humidity_d1  \
# 0         100    10.57     5.66     5.03     8.37     8.91           83
# 1         100    10.80     6.68     6.31     8.65    11.82           84
# 2         100     8.77     5.51     5.41     7.70     7.57           87
# 3         100    11.59     7.87     7.39     9.38     8.88           77
# 4         100     8.45     4.77     5.38     8.20     4.84           80
# 5         100     7.24     4.13     4.92     8.10     4.60           70
# 6         100     8.57     5.67     5.25     6.58     5.03           78
# 7         100     8.12     5.92     6.35     7.96     6.31           71
# 8         100     7.51     5.39     2.86     4.22     0.74           71
# 9         100     7.08     2.90     1.85     3.72     1.05           78
# 10         89     7.35     4.13     2.12     3.85     1.79           76
# 11         89     7.39     3.58     2.05     3.50     1.86           77
# 12        100     6.71     4.76     3.00     8.72     5.37           85
# 13        100     7.09     4.10     4.72    11.91     7.44           84
# 14         98     3.34     2.44     1.84     2.89     2.02           98
# 15        100     2.47     1.99     1.83     2.86     2.16           96
# 16        100     4.47     3.42     3.13     6.78     5.68           69
# 17         99     2.17     2.13     2.15     2.67     1.52           97
# 18         76     5.36     7.73     6.30     3.72     3.74           92
# 19        100     2.17     7.75     6.91     5.21     5.60           88
# 20         99     2.05     7.60     6.89     6.32     5.35           87
# 21         97     0.62     4.28     3.35     4.78     3.09           90
# 22        100     6.18     3.92     1.55     6.55     3.60           84
# 23        100     6.78     4.10     3.00     4.68     4.54           65
# 24        100     7.62     4.78     3.32     4.65     5.30           62
# 25         99     9.48     5.41     4.75     4.92     5.22           63
# 26        100    11.18     6.40     4.91     6.79     5.82           81
# 27        100    10.02     2.20     2.57     1.76     2.68           71
# 28         92     9.31     5.15     6.04     3.88     8.38           88
# 29         99     3.15     2.11     2.34     2.12     3.99           96
# 30        100     6.11     6.69     5.96     2.20     7.27           82
# 31        100     6.43     5.76     5.32     4.45     6.74           81
# 32         99     7.17     6.91     5.59    12.26     7.93           70
# 33         98     6.25     5.61     4.95    11.21     6.79           72
# 34         96    11.11     6.96     5.28    17.61    11.15           70
#
#     humidity_d2  humidity_d3  humidity_d4  humidity_d5  pop_d1  pop_d2  \
# 0            87           88           84           93    0.59    0.47
# 1            80           83           83           90    0.68    0.48
# 2            90           91           84           92    0.72    0.63
# 3            80           82           82           89    0.77    0.54
# 4            86           93           87           92    0.93    0.18
# 5            72           81           79           86    0.92    0.00
# 6            84           92           88           92    0.92    0.07
# 7            78           85           92           89    0.46    0.29
# 8            79           82           81           91    1.00    0.21
# 9            84           88           91           91    1.00    0.37
# 10           81           88           92           88    1.00    0.42
# 11           81           89           94           88    1.00    0.43
# 12           87           83           76           88    1.00    0.38
# 13           85           86           90           93    0.69    0.02
# 14           97           92           95           96    1.00    0.99
# 15           88           88           93           97    1.00    0.96
# 16           74           62           84           79    1.00    0.34
# 17           94           84           96           95    0.85    0.00
# 18           63           58           91           75    0.51    0.00
# 19           62           65           90           71    0.36    0.00
# 20           60           64           87           68    0.41    0.00
# 21           67           69           92           77    0.56    0.00
# 22           69           70           83           73    0.89    0.00
# 23           71           71           89           74    1.00    0.00
# 24           67           65           91           70    0.95    0.00
# 25           63           64           87           63    0.90    0.00
# 26           63           64           84           63    0.83    0.00
# 27           79           76           83           78    0.30    0.34
# 28           81           82           92           69    0.93    0.45
# 29           88           90           82           74    1.00    0.60
# 30           85           88           91           80    0.91    0.76
# 31           90           93           93           90    0.87    0.91
# 32           84           86           75           67    0.95    1.00
# 33           87           88           75           68    0.96    1.00
# 34           81           76           80           71    0.86    0.99
#
#     pop_d3  pop_d4  pop_d5  rain_d1  rain_d2  rain_d3  rain_d4  rain_d5
# 0     0.28    0.39    0.91     0.39     0.57     0.32     0.12     0.83
# 1     0.23    0.35    0.99     0.37     0.29     0.18     0.00     1.78
# 2     0.33    0.45    0.95     0.71     0.34     0.12     0.26     2.73
# 3     0.57    0.61    0.74     1.12     0.61     0.98     0.53     0.79
# 4     0.40    0.76    0.37     0.82     0.00     0.22     1.70     0.21
# 5     0.55    0.94    0.91     0.50     0.00     0.25     4.93     0.66
# 6     0.41    0.99    0.72     1.07     0.00     0.29     2.04     0.36
# 7     0.51    1.00    0.75     0.15     0.13     0.32     6.68     0.40
# 8     0.00    0.81    0.03     1.54     0.00     0.00     0.85     0.00
# 9     0.00    0.98    0.19     2.98     0.00     0.00     1.32     0.00
# 10    0.00    0.98    0.39     3.19     0.00     0.00     2.44     0.16
# 11    0.00    0.99    0.21     3.63     0.00     0.00     3.06     0.24
# 12    0.00    1.00    0.63     5.07     0.16     0.00     2.68     0.18
# 13    0.00    1.00    0.86     0.24     0.00     0.00     1.75     1.08
# 14    0.00    1.00    0.85     7.89     0.00     0.00     1.69     1.18
# 15    0.00    1.00    0.71     1.98     0.00     0.00     2.25     0.14
# 16    0.00    0.84    0.56     7.37     0.00     0.00     0.49     0.46
# 17    0.00    1.00    0.36     0.69     0.00     0.00     1.31     0.21
# 18    0.00    0.98    0.45     0.49     0.00     0.00     1.69     0.25
# 19    0.00    0.92    0.32     0.34     0.00     0.00     1.15     0.25
# 20    0.00    0.83    0.22     0.34     0.00     0.00     0.91     0.00
# 21    0.00    0.93    0.17     0.38     0.00     0.00     0.50     0.00
# 22    0.00    0.68    0.04     1.59     0.00     0.00     0.37     0.00
# 23    0.00    0.52    0.06     1.79     0.00     0.00     0.14     0.00
# 24    0.00    0.35    0.02     1.48     0.00     0.00     0.00     0.00
# 25    0.00    0.07    0.00     0.59     0.00     0.00     0.00     0.00
# 26    0.00    0.14    0.00     0.65     0.00     0.00     0.00     0.00
# 27    0.04    0.00    0.44     0.00     0.26     0.00     0.00     0.95
# 28    0.58    0.21    0.26     2.78     0.21     0.54     0.00     0.00
# 29    0.58    0.63    0.34     4.19     0.65     0.50     0.10     0.00
# 30    0.64    0.90    0.28     0.99     0.82     0.38     2.99     0.00
# 31    0.78    1.00    0.61     0.31     2.08     0.67     3.70     1.71
# 32    0.82    0.75    0.62     1.01     7.06     2.14     2.10     1.46
# 33    0.84    0.77    0.60     1.03     7.58     2.37     2.28     1.26
# 34    0.48    0.70    0.34     0.99     1.99     0.37     0.45     0.10

# %%
dataset.describe(include='all')
# Out:
#           city_id               city   lat_city   lon_city    temp_d1  \
# count   35.000000                 35  35.000000  35.000000  35.000000
# unique        NaN                 35        NaN        NaN        NaN
# top           NaN  Mont Saint Michel        NaN        NaN        NaN
# freq          NaN                  1        NaN        NaN        NaN
# mean    18.000000                NaN  45.842672   3.401638   8.495429
# std     10.246951                NaN   2.588229   2.950550   2.720422
# min      1.000000                NaN  42.525050  -2.026041   4.530000
# 25%      9.500000                NaN  43.512178   1.399623   6.280000
# 50%     18.000000                NaN  45.187560   4.360069   7.750000
# 75%     26.500000                NaN  48.417068   5.637707  10.285000
# max     35.000000                NaN  50.636565   7.750713  13.960000
#
#           temp_d2    temp_d3    temp_d4    temp_d5 weather_d1 weather_d2  \
# count   35.000000  35.000000  35.000000  35.000000         35         35
# unique        NaN        NaN        NaN        NaN          2          3
# top           NaN        NaN        NaN        NaN       Rain     Clouds
# freq          NaN        NaN        NaN        NaN         34         19
# mean     5.402857   5.508000   8.212000   7.128286        NaN        NaN
# std      2.386132   2.632504   2.614947   1.932145        NaN        NaN
# min      0.050000  -0.910000   2.090000   2.050000        NaN        NaN
# 25%      3.900000   4.090000   6.760000   6.040000        NaN        NaN
# 50%      5.180000   5.840000   8.600000   7.200000        NaN        NaN
# 75%      6.870000   7.335000   9.445000   8.005000        NaN        NaN
# max     10.310000   9.320000  12.670000  10.260000        NaN        NaN
#
#        weather_d3 weather_d4 weather_d5   clouds_d1   clouds_d2   clouds_d3  \
# count          35         35         35   35.000000   35.000000   35.000000
# unique          3          2          2         NaN         NaN         NaN
# top          Rain       Rain       Rain         NaN         NaN         NaN
# freq           15         29         23         NaN         NaN         NaN
# mean          NaN        NaN        NaN   90.371429   77.942857   60.171429
# std           NaN        NaN        NaN   20.578524   25.833110   38.891618
# min           NaN        NaN        NaN   17.000000   15.000000    1.000000
# 25%           NaN        NaN        NaN   97.500000   68.000000   18.500000
# 50%           NaN        NaN        NaN  100.000000   88.000000   71.000000
# 75%           NaN        NaN        NaN  100.000000   98.500000   98.500000
# max           NaN        NaN        NaN  100.000000  100.000000  100.000000
#
#          clouds_d4   clouds_d5    wind_d1    wind_d2    wind_d3    wind_d4  \
# count    35.000000   35.000000  35.000000  35.000000  35.000000  35.000000
# unique         NaN         NaN        NaN        NaN        NaN        NaN
# top            NaN         NaN        NaN        NaN        NaN        NaN
# freq           NaN         NaN        NaN        NaN        NaN        NaN
# mean     95.742857   98.000000   6.876571   4.983143   4.303429   6.262000
# std      10.404589    4.789695   2.894440   1.735079   1.764229   3.427132
# min      56.000000   76.000000   0.620000   1.990000   1.550000   1.760000
# 25%     100.000000   99.000000   5.735000   4.010000   2.715000   3.785000
# 50%     100.000000  100.000000   7.170000   5.150000   4.910000   5.210000
# 75%     100.000000  100.000000   8.670000   6.160000   5.500000   8.150000
# max     100.000000  100.000000  11.590000   7.870000   7.390000  17.610000
#
#           wind_d5  humidity_d1  humidity_d2  humidity_d3  humidity_d4  \
# count   35.000000    35.000000    35.000000    35.000000    35.000000
# unique        NaN          NaN          NaN          NaN          NaN
# top           NaN          NaN          NaN          NaN          NaN
# freq          NaN          NaN          NaN          NaN          NaN
# mean     5.279429    80.085714    79.057143    80.171429    86.742857
# std      2.746507     9.838016     9.857642    10.592688     5.797276
# min      0.740000    62.000000    60.000000    58.000000    75.000000
# 25%      3.345000    71.000000    71.500000    70.500000    83.000000
# 50%      5.300000    81.000000    81.000000    83.000000    87.000000
# 75%      7.030000    87.000000    86.500000    88.000000    91.500000
# max     11.820000    98.000000    97.000000    93.000000    96.000000
#
#         humidity_d5     pop_d1     pop_d2     pop_d3     pop_d4     pop_d5  \
# count     35.000000  35.000000  35.000000  35.000000  35.000000  35.000000
# unique          NaN        NaN        NaN        NaN        NaN        NaN
# top             NaN        NaN        NaN        NaN        NaN        NaN
# freq            NaN        NaN        NaN        NaN        NaN        NaN
# mean      81.714286   0.820571   0.366571   0.229714   0.727714   0.454286
# std       10.637258   0.209438   0.356717   0.292539   0.304622   0.306578
# min       63.000000   0.300000   0.000000   0.000000   0.000000   0.000000
# 25%       72.000000   0.705000   0.000000   0.000000   0.565000   0.215000
# 50%       86.000000   0.910000   0.340000   0.000000   0.830000   0.390000
# 75%       91.000000   1.000000   0.570000   0.495000   0.985000   0.715000
# max       97.000000   1.000000   1.000000   0.840000   1.000000   0.990000
#
#           rain_d1    rain_d2    rain_d3    rain_d4    rain_d5
# count   35.000000  35.000000  35.000000  35.000000  35.000000
# unique        NaN        NaN        NaN        NaN        NaN
# top           NaN        NaN        NaN        NaN        NaN
# freq          NaN        NaN        NaN        NaN        NaN
# mean     1.676000   0.650000   0.275714   1.442286   0.496857
# std      1.924202   1.740054   0.548116   1.527216   0.657396
# min      0.000000   0.000000   0.000000   0.000000   0.000000
# 25%      0.440000   0.000000   0.000000   0.200000   0.000000
# 50%      0.990000   0.000000   0.000000   1.150000   0.210000
# 75%      1.885000   0.315000   0.320000   2.175000   0.810000
# max      7.890000   7.580000   2.370000   6.680000   2.730000

# %% [markdown]
# ## Enregistrement fichier csv

# %%
# Enregistrement fichier csv
# Top 35 villes françaises avec données gps et météo
dataset.to_csv('./src/top_35_cities.csv', index=False)

# %%
dataset = pd.read_csv('./src/top_35_cities.csv')

# %% [markdown]
# ## Simplification du dataframe

# %% [markdown]
# Nous simplifions le dataframe obtenu en calculant les valeurs moyennes pour les 5 prochains jours.

# %%
# Calcul des valeurs moyennes pour les 5 prochains jours 

dataset['avg_temp'] = dataset.filter(like='temp_d').mean(axis=1)
dataset['avg_clouds'] = dataset.filter(like='clouds_d').mean(axis=1)
dataset['avg_wind'] = dataset.filter(like='wind_d').mean(axis=1)
dataset['avg_humidity'] = dataset.filter(like='humidity_d').mean(axis=1)
dataset['avg_pop'] = dataset.filter(like='pop_d').mean(axis=1)
dataset['avg_rain'] = dataset.filter(like='rain_d').mean(axis=1)
dataset['avg_weather'] = dataset.filter(like='weather_d').mode(axis=1).iloc[:,0]

# %%
dataset_lite = dataset[['city_id', 'city', 'lat_city', 'lon_city', 
                      'avg_weather', 'avg_temp', 'avg_clouds', 'avg_wind',
                      'avg_humidity', 'avg_rain', 'avg_pop',]].copy()
dataset_lite.head(35)
# Out:
#     city_id                          city   lat_city  lon_city avg_weather  \
# 0         1             Mont Saint Michel  48.635954 -1.511460        Rain
# 1         2                       St Malo  48.649518 -2.026041        Rain
# 2         3                        Bayeux  49.276462 -0.702474        Rain
# 3         4                      Le Havre  49.493898  0.107973        Rain
# 4         5                         Rouen  49.440459  1.093966        Rain
# 5         6                         Paris  48.858890  2.320041        Rain
# 6         7                        Amiens  49.894171  2.295695        Rain
# 7         8                         Lille  50.636565  3.063528        Rain
# 8         9                    Strasbourg  48.584614  7.750713      Clouds
# 9        10  Chateau du Haut Koenigsbourg  48.249523  7.345492      Clouds
# 10       11                        Colmar  48.077752  7.357964        Rain
# 11       12                     Eguisheim  48.044797  7.307962        Rain
# 12       13                      Besancon  47.238022  6.024362        Rain
# 13       14                         Dijon  47.321581  5.041470        Rain
# 14       15                        Annecy  45.899235  6.128885        Rain
# 15       16                      Grenoble  45.187560  5.735782        Rain
# 16       17                          Lyon  45.757814  4.832011        Rain
# 17       18              Gorges du Verdon  43.749656  6.328562        Rain
# 18       19            Bormes les Mimosas  43.150697  6.341928        Rain
# 19       20                        Cassis  43.214036  5.539632        Rain
# 20       21                     Marseille  43.296174  5.369953      Clouds
# 21       22               Aix en Provence  43.529842  5.447474      Clouds
# 22       23                       Avignon  43.949249  4.805901      Clouds
# 23       24                          Uzes  44.012128  4.419672      Clouds
# 24       25                         Nimes  43.837425  4.360069      Clouds
# 25       26                 Aigues Mortes  43.566152  4.191540      Clouds
# 26       27      Saintes Maries de la mer  43.451592  4.427720      Clouds
# 27       28                     Collioure  42.525050  3.083155      Clouds
# 28       29                   Carcassonne  43.213036  2.349107        Rain
# 29       30                        Ariege  42.992743  1.612497        Rain
# 30       31                      Toulouse  43.604462  1.444247        Rain
# 31       32                     Montauban  44.017584  1.354999        Rain
# 32       33                      Biarritz  43.483252 -1.559278        Rain
# 33       34                       Bayonne  43.494514 -1.473666        Rain
# 34       35                   La Rochelle  46.159113 -1.152043        Rain
#
#     avg_temp  avg_clouds  avg_wind  avg_humidity  avg_rain  avg_pop
# 0      5.668        82.6     7.708          87.0     0.446    0.528
# 1      6.324        84.0     8.852          84.0     0.524    0.546
# 2      5.518        71.2     6.992          88.8     0.832    0.616
# 3      7.252        74.2     9.022          82.0     0.806    0.646
# 4      5.518        80.2     6.328          87.6     0.590    0.528
# 5      6.874        93.8     5.798          77.6     1.268    0.664
# 6      5.940        87.8     6.220          86.8     0.752    0.622
# 7      5.448        93.8     6.932          83.0     1.536    0.602
# 8      5.882        77.4     4.144          80.8     0.478    0.410
# 9      2.034        79.0     3.320          86.4     0.860    0.508
# 10     5.362        78.6     3.848          85.0     1.158    0.558
# 11     5.314        79.4     3.676          85.8     1.386    0.526
# 12     5.754        87.2     5.712          83.8     1.618    0.602
# 13     5.084        98.8     7.052          87.6     0.614    0.514
# 14     3.954        93.0     2.506          95.6     2.152    0.768
# 15     5.836        84.6     2.262          92.4     0.874    0.734
# 16     6.910       100.0     4.696          73.6     1.664    0.548
# 17     2.422        70.6     2.128          93.2     0.442    0.442
# 18    10.280        63.6     5.370          75.8     0.486    0.388
# 19    11.072        64.8     5.528          75.2     0.348    0.320
# 20    11.240        63.0     5.642          73.2     0.250    0.292
# 21     8.040        64.2     3.224          79.0     0.176    0.332
# 22     8.430        89.8     4.360          75.8     0.392    0.322
# 23     7.454        94.2     4.620          74.0     0.386    0.316
# 24     8.450        95.6     5.134          71.0     0.296    0.264
# 25    10.158        91.0     5.956          68.0     0.118    0.194
# 26    10.652        81.6     7.020          71.0     0.130    0.194
# 27     8.358        69.8     3.846          77.4     0.242    0.224
# 28     6.870        91.6     6.552          82.4     0.706    0.486
# 29     5.834        96.6     2.742          86.0     1.088    0.630
# 30     6.434        99.4     5.646          85.2     1.036    0.698
# 31     6.368        99.6     5.740          89.4     1.694    0.834
# 32     9.294        99.8     7.972          76.4     2.754    0.828
# 33     8.984        99.6     6.962          78.0     2.904    0.834
# 34     8.214        75.2    10.422          75.6     0.780    0.674

# %%
dataset_lite.describe(include='all')
# Out:
#           city_id               city   lat_city   lon_city avg_weather  \
# count   35.000000                 35  35.000000  35.000000          35
# unique        NaN                 35        NaN        NaN           2
# top           NaN  Mont Saint Michel        NaN        NaN        Rain
# freq          NaN                  1        NaN        NaN          25
# mean    18.000000                NaN  45.842672   3.401638         NaN
# std     10.246951                NaN   2.588229   2.950550         NaN
# min      1.000000                NaN  42.525050  -2.026041         NaN
# 25%      9.500000                NaN  43.512178   1.399623         NaN
# 50%     18.000000                NaN  45.187560   4.360069         NaN
# 75%     26.500000                NaN  48.417068   5.637707         NaN
# max     35.000000                NaN  50.636565   7.750713         NaN
#
#          avg_temp  avg_clouds   avg_wind  avg_humidity   avg_rain    avg_pop
# count   35.000000   35.000000  35.000000     35.000000  35.000000  35.000000
# unique        NaN         NaN        NaN           NaN        NaN        NaN
# top           NaN         NaN        NaN           NaN        NaN        NaN
# freq          NaN         NaN        NaN           NaN        NaN        NaN
# mean     6.949314   84.445714   5.540914     81.554286   0.908171   0.519771
# std      2.216783   11.825803   1.989231      6.888197   0.698629   0.183944
# min      2.034000   63.000000   2.128000     68.000000   0.118000   0.194000
# 25%      5.593000   76.300000   3.996000     75.800000   0.417000   0.360000
# 50%      6.434000   84.600000   5.646000     82.400000   0.752000   0.528000
# 75%      8.394000   94.000000   6.947000     86.600000   1.213000   0.638000
# max     11.240000  100.000000  10.422000     95.600000   2.904000   0.834000

# %%
# Enregistrement fichier csv 
# Top 35 villes françaises avec données gps et météo en version lite
dataset_lite.to_csv('./src/top_35_cities_lite.csv', index=False)

# %%
dataset_lite = pd.read_csv('./src/top_35_cities_lite.csv')

# %% [markdown]
# ## Les 5 meilleures destinations

# %% [markdown]
# ### Villes supérieures à la moyenne
#
# Nous nous intéressons aux villes dont les données météorologiques sont meilleures que la moyenne.

# %%
# Création de masques basés sur la moyenne

min_temp = dataset_lite['avg_temp'] >= dataset_lite['avg_temp'].mean()
max_wind = dataset_lite['avg_wind'] <= dataset_lite['avg_wind'].mean()
max_clouds = dataset_lite['avg_clouds'] <= dataset_lite['avg_clouds'].mean()
max_rain = dataset_lite['avg_rain'] <= dataset_lite['avg_rain'].mean()
max_pop = dataset_lite['avg_pop'] <= dataset_lite['avg_pop'].mean()
max_humidity = dataset_lite['avg_humidity'] <= dataset_lite['avg_humidity'].mean()

# %%
best_destinations_lite = dataset_lite[min_temp & max_clouds & max_rain & max_pop & max_humidity & max_wind]
best_destinations_lite = best_destinations_lite.reset_index(drop=True)
print(len(best_destinations_lite))
best_destinations_lite
# Out:
# 4
#    city_id                city   lat_city  lon_city avg_weather  avg_temp  \
# 0       19  Bormes les Mimosas  43.150697  6.341928        Rain    10.280
# 1       20              Cassis  43.214036  5.539632        Rain    11.072
# 2       22     Aix en Provence  43.529842  5.447474      Clouds     8.040
# 3       28           Collioure  42.525050  3.083155      Clouds     8.358
#
#    avg_clouds  avg_wind  avg_humidity  avg_rain  avg_pop
# 0        63.6     5.370          75.8     0.486    0.388
# 1        64.8     5.528          75.2     0.348    0.320
# 2        64.2     3.224          79.0     0.176    0.332
# 3        69.8     3.846          77.4     0.242    0.224

# %% [markdown]
# Cette méthode est trop restrictive : nous n'obtenons que 4 villes au moment où ce notebook est édité (novembre).
#
# Par conséquent nous tentons une méthode différente.

# %% [markdown]
# ### Ordonner les villes
#
# Nous choisissons d'ordonner les villes par rapport à ces critères et dans cet ordre :
#
# 1. la vitesse du vent
#
# 2. la probabilité de pleuvoir
#
# 3. le taux de nuages
#
# 4. le taux d'humidité
#
# 5. la température

# %%
dataset_sorted = dataset_lite.sort_values(['avg_wind', 'avg_pop', 'avg_clouds', 'avg_humidity', 'avg_temp'], 
                                        ascending=[True, True, True, True, False])
dataset_sorted.head(5)
# Out:
#     city_id              city   lat_city  lon_city avg_weather  avg_temp  \
# 17       18  Gorges du Verdon  43.749656  6.328562        Rain     2.422
# 15       16          Grenoble  45.187560  5.735782        Rain     5.836
# 14       15            Annecy  45.899235  6.128885        Rain     3.954
# 29       30            Ariege  42.992743  1.612497        Rain     5.834
# 21       22   Aix en Provence  43.529842  5.447474      Clouds     8.040
#
#     avg_clouds  avg_wind  avg_humidity  avg_rain  avg_pop
# 17        70.6     2.128          93.2     0.442    0.442
# 15        84.6     2.262          92.4     0.874    0.734
# 14        93.0     2.506          95.6     2.152    0.768
# 29        96.6     2.742          86.0     1.088    0.630
# 21        64.2     3.224          79.0     0.176    0.332

# %% [markdown]
# Les 5 premières villes qui ressortent sont concentrées géographiquement.
#
# Cela semble logique puisque les villes partageant des données météorologiques proches sont susceptibles d'être géographiquement proches.

# %% [markdown]
# ### Varier les régions représentées
#
# Pour apporter de la variété dans les villes sélectionnées, nous ajoutons le critère de latitude.
#
# --> Nous construisons 5 intervalles de latitudes et choisissons la meilleure ville de chaque intervalle.

# %%
lat_interval = []
for i in [x / 10.0 for x in range(0, 11, 2)]:
    lat_interval.append(np.quantile(dataset_sorted['lat_city'], i))
lat_interval
# Out:
# [42.52505,
#  43.476920279999995,
#  43.90451954,
#  46.59067644,
#  48.63866688,
#  50.6365654]

# %%
best = []
for i in range(len(lat_interval)-1):
    city = dataset_sorted[(dataset_sorted['lat_city'] > lat_interval[i]) & (dataset_sorted['lat_city'] < lat_interval[i+1])].iloc[0]['city']
    best.append(city)
best
# Out:
# ['Ariege',
#  'Gorges du Verdon',
#  'Grenoble',
#  'Chateau du Haut Koenigsbourg',
#  'Paris']

# %%
best_destinations_lite = dataset_lite[(dataset_lite['city'] == best[0]) | 
                                 (dataset_lite['city'] == best[1]) | 
                                 (dataset_lite['city'] == best[2]) |
                                 (dataset_lite['city'] == best[3]) |
                                 (dataset_lite['city'] == best[4])]
best_destinations_lite.sort_values(['avg_wind', 'avg_pop', 'avg_clouds', 'avg_humidity', 'avg_temp'], 
                                        ascending=[True, True, True, True, False])

# %% [markdown]
# ### Enregistrement fichiers csv

# %%
# Enregistrement fichier csv
# Top 5 destinations françaises
best_destinations_lite.to_csv('./src/top_5_destinations.csv', index=False)

# %%
best_destinations_lite = pd.read_csv('./src/top_5_destinations.csv')

# %% [markdown]
# ## Visualisation sur carte

# %%
import plotly.express as px
fig = px.scatter_mapbox(best_destinations_lite, 
                        lat = "lat_city", lon = "lon_city", 
                        color = "avg_temp",
                        size = "avg_temp",
                        hover_name = "city",
                        hover_data = {"lat_city": ":.2f", "lon_city": ":.2f", "avg_temp": ":.0f"},
                        mapbox_style = "carto-positron",
                        zoom = 4,
                        center = {'lat':46.232192999999995,'lon':2.209666999999996},
                        color_continuous_scale=px.colors.sequential.Bluered)
fig.update_layout(title_text = "Top 5 destinations in France", title_x = 0.5)
fig.show()
